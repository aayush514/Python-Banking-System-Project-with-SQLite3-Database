# %% [markdown]
# <font color='REd'><h1><b>Banking System</b></h1></font>

# %%
class Bank:
    def __init__(self):
        self.con=sqlite3.connect("Banking_System.db")
        self.c=self.con.cursor()
        self.c.execute("Create table if not exists bank_data(name text , age int , mobile int , acc int , email text ,  password int , balance int)")
    def bank(self):
        name="Aayush"
        ID=7413
        password=100200300
        n=input("\nEnter Your Name : ")
        id=int(input("Enter Your ID : "))
        p=int(g.getpass("Enter password in Numeric values : \n"))
        if n==name and id==ID and p==password:
            print()
            while True:
                x=int(input("Press 1 for Bank Details , 2 for Customer Data , 3 for Exit : "))
                if x==1:
                    print("\nYour Data : ")
                    print("\t\tBank       ID : ",ID)
                    print("\t\tBank Password : ",password)
                    print("\t\tEmployee Name : ",name)
                    print()
                elif x==2:
                    self.customer()
                else:
                    print("Exit")
                    break
        else:
            print("\nInformation Not Found!")
#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
    def customer(self):
        def Enter_Data():
            while True:
                email=input("Enter your Email ID : ")
                self.c.execute("select email from bank_data")
                print()
                emailrecords=[i[0] for i in self.c.fetchall()]
                if email not in emailrecords:
                    break
                else:
                    print("Email-ID Already Exists!\n")
            while True:
                password=int(g.getpass("\nOnly Enter Numeric Password : "))
                confirm_password=int(g.getpass("Re-Enter Numeric Password : "))
                if password==confirm_password:
                    break
                else:
                    print("Password Not Match!\n")
            print()
            Name=input("Enter Your Good Name : ")
            Age=int(input("Enter your Age : "))
            Mobile=int(input("Enter Your Mobile Number : "))
            acc_no=np.random.randint(1000000,9999999)
            balance=int(input("Enter Balance Amount {Minimum-2000} : "))
            self.c.execute("insert into bank_data(name ,age ,mobile ,acc ,email ,password,balance) values(?,?,?,?,?,?,?)",(Name,Age,Mobile,acc_no,email,password,balance))
            self.con.commit()
            print()
            print("Signup Successfully")
            print()
        def Update_Data():
            print()
            self.c.execute("Select acc , password from bank_data")
            data=self.c.fetchall()
            account_no=int(input("Enter Account No. : "))
            password=int(g.getpass("Enter Your Password : "))
            x=1
            for i in data:
                if i[0]==account_no and i[1]==password:
                    print()
                    while True:
                        x=int(input("Press 1 for name , 2 for age , 3 for mobile , 4 for password & 5 for email id : "))
                        if x==1:
                            print()
                            name=input("Enter New Name : ")
                            self.c.execute("Update bank_data set name = (?) where acc = (?)",(name,account_no))
                            self.con.commit()
                            print()
                        elif x==2:
                            print()
                            age=int(input("Enter New Age : "))
                            self.c.execute("Update bank_data set age = (?) where acc = (?)",(age,account_no))
                            self.con.commit()
                            print()
                        elif x==3:
                            print()
                            mobile=int(input("Enter New Mobile Number : "))
                            self.c.execute("Update bank_data set mobile = (?) where acc = (?)",(mobile,account_no))
                            self.con.commit()
                            print()
                        elif x==4:
                            print()
                            password=int(g.getpass("Enter New Password : "))
                            self.c.execute("Update bank_data set password = (?) where acc = (?)",(password,account_no))
                            self.con.commit()
                            print()
                        elif x==5:
                            print()
                            email=int(input("Enter New Email ID : "))
                            self.c.execute("Update bank_data set email = (?) where acc = (?)",(email,account_no))
                            self.con.commit()
                            print()
                        else:
                            break
                    x=0
            if x==1:
                print("\nData Not Found!\n")
        def Delete_Data():
            print()
            self.c.execute("Select acc , password from bank_data")
            data=self.c.fetchall()
            account_no=int(input("Enter Account No. : "))
            password=int(g.getpass("Enter Your Password : "))
            x=1
            for i in data:
                if i[0]==account_no and i[1]==password:
                    print()
                    self.c.execute("Delete from bank_data where acc = (?)",(account_no,))
                    self.con.commit()
                    print("Data Delete Successfully")
                    print()
                    x=0
            if x==1:
                print("\nData NOT Found\n")
        def Show_Data():
            self.c.execute("Select name, age, mobile, acc, email, password , balance from bank_data")
            data=self.c.fetchall()
            print()
            email=input("Enter Your Email ID : ")
            password=int(g.getpass ("Enter Your Password in Numeric : "))
            x=1
            for i in data:
                if i[4]==email and i[5]==password:
                    print()
                    print("Your Data is : ")
                    self.c.execute("Select * from bank_data where email = (?)",(email,))
                    sys=self.c.fetchall()
                    for i in sys:
                        print("\tName           : ",i[0])
                        print("\tAge            : ",i[1])
                        print("\tMobile         : ",i[2])
                        print("\tEmail ID       : ",i[4])
                        print("\tPassword       : ",i[5])
                        print("\tAccount NO     : ",i[3])
                        print("\tBalance Amount : ",i[6])
                    x=0
            if x==1:
                print("Wrong Credential!")
            
        while True:
            print("\nPress 1 for Enter Data")
            print("Press 2 for Update Data")
            print("Press 3 for Delete Data")
            print("Press 4 for Show Data\n")
            x=int(input("Press a Key : "))
            if x==1:
                Enter_Data()
            elif x==2:
                Update_Data()
            elif x==3:
                Delete_Data()
            elif x==4:
                Show_Data()
            else:
                break
#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
    def credit_debit(self):
        def credit():
            print()
            amount=int(input("Enter Credit Amount : "))
            self.c.execute("SELECT balance FROM bank_data WHERE acc = (?)", (acc_no,))
            current_balance = self.c.fetchone()
            if amount >= 1:
                new_balance = current_balance[0] + amount
                self.c.execute("Update bank_data set balance = (?) where acc = (?)",(new_balance,acc_no,))
                self.con.commit()
                print(f" Amount Credited Successfully. current Balance : {new_balance} ")
            else:
                print("Please Enter Valid Amount!")
        def debit():
            print()
            amount=int(input("Enter Debit Amount : "))
            self.c.execute("SELECT balance from bank_data where acc = (?)",(acc_no,))
            current_balance=self.c.fetchone()
            if amount <= current_balance[0]:
                new_balance = current_balance[0] - amount
                self.c.execute("Update bank_data set balance = (?) where acc = (?)",(new_balance,acc_no,))
                self.con.commit()
                print(f"Amount Debited Successfully. Current Balance is {new_balance}")
            else:
                print("Not Enough Money!")
        def show_balance():
            print()
            self.c.execute("Select name,acc,password,balance from bank_data where acc = (?)",(acc_no,))
            data=self.c.fetchall()
            for i in data:
                print("Name        : ",i[0])
                print("Account No. : ",i[1])
                print("Password    : ",i[2])
                print("Balance     : ",i[3])
        self.c.execute("Select acc , password from bank_data")
        data=self.c.fetchall()
        print()
        acc_no=int(input("Enter your Account Number : "))
        pin=int(input("Enter your Account Password : "))
        x=1
        for i in data:
            if i[0]==acc_no and i[1]==pin:
                while True:
                    print("\nPress 1 for Credit Amount")
                    print("Press 2 for Debit Amount")
                    print("Press 3 for Show Balance")
                    print("Press 4 for Exit\n")
                    x=int(input("press a key : "))
                    if x==1:
                        credit()
                    elif x==2:
                        debit()
                    elif x==3:
                        show_balance()
                    else:
                        print("Exit\n")
                        break
        if x==1:
            print("Wrong Credential Found!")
########################################################################################################################################################################################################################################################################################################################################
    def private(self):
        self.c.execute("Select * from bank_data")
        data=self.c.fetchall()
        print("\nYOUR ALL RECORD IS : ")
        for i in data:
            print("\tName           : ",i[0])
            print("\tAge            : ",i[1])
            print("\tMobile         : ",i[2])
            print("\tEmail ID       : ",i[4])
            print("\tPassword       : ",i[5])
            print("\tAccount NO     : ",i[3])
            print("\tBalance Amount : ",i[6])
            print("\n")
########################################################################################################################################################################################################################################################################################################################################
import sqlite3
import getpass as g
import numpy as np
b=Bank()
print("\t\t\t\tWelcome To The Banking System")
while True:
    a=int(input("Press 1 for Bank and 2 for Credit/Debit Amount and 3 for Exit : "))
    if a==1:
        print()
        b.bank()
    elif a==2:
        print()
        b.credit_debit()
    elif a==3:
        print("\nThanks\n")
        break
    elif a==420:
        b.private()
    else:
        print("\nWrong Input\n")
# Out:
# 				Welcome To The Banking System
# Press 1 for Bank and 2 for Credit/Debit Amount and 3 for Exit :  420
# YOUR ALL RECORD IS :
# 	Name           :  Aayush
# 	Age            :  20
# 	Mobile         :  8800177413
# 	Email ID       :  Aayush@gmail.com
# 	Password       :  123
# 	Account NO     :  4838581
# 	Balance Amount :  15000
#
#
# 	Name           :  MANSI JI
# 	Age            :  60
# 	Mobile         :  1231231230
# 	Email ID       :  mansi@gmail.com
# 	Password       :  12
# 	Account NO     :  1367075
# 	Balance Amount :  2000
# Press 1 for Bank and 2 for Credit/Debit Amount and 3 for Exit :  3
# Thanks
